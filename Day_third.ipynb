# %% [markdown]
# #### Agend
#  - OCR and Use Cases
#  - Library
#  - CRNN
#  - Pratical

# %% [markdown]
# ### OCR
# - ocr means to extract the text throw the images(that time we are use the textual images like Number Plate)
# - We are use Four Library
#     - Tesseremt  (Hp Libary now google handle now they are use LSTM concept , with hyperparameter)
#     - Keras OCR (All these last three library is CRNN)= CNN + RNN
#     - easy ocr
#     - paddle ocr\
# - Concept
#     - Text Extraction
#         - Text Detection - text present ( algo RCNN Faster RCNN , SSd , YOLO)
#         - Text Recognation ( Text Location find out )

# %%
# All Library Install
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import cv2
import pytesseract
import keras_ocr
# Out:
# Unexpected exception formatting exception. Falling back to standard exception
# Traceback (most recent call last):
#   File "c:\Users\Sachin2\Desktop\Project\eKYC\myenv\lib\site-packages\IPython\core\interactiveshell.py", line 3550, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "C:\Users\Sachin2\AppData\Local\Temp\ipykernel_8208\1476599624.py", line 7, in <module>
#     import keras_ocr
#   File "c:\Users\Sachin2\Desktop\Project\eKYC\myenv\lib\site-packages\keras_ocr\__init__.py", line 1, in <module>
#     from . import (
#   File "c:\Users\Sachin2\Desktop\Project\eKYC\myenv\lib\site-packages\keras_ocr\detection.py", line 28, in <module>
#     import efficientnet.tfkeras as efficientnet
#   File "c:\Users\Sachin2\Desktop\Project\eKYC\myenv\lib\site-packages\efficientnet\tfkeras.py", line 4, in <module>
#     from .preprocessing import center_crop_and_resize
# ...

# %%
path = "images/Pan_Back.png"
img_read = cv2.imread(path)
gray = cv2.cvtColor(img_read , cv2.COLOR_BGR2GRAY)
plt.imshow(gray , cmap='gray')

# %% [markdown]
# ### This is First Method to exxtract the data using the

# %%
custom_config = r'--oem 3 --psm 3 -l eng+osd --tessdata-dir "C:\\Program Files\\Tesseract-OCR\\tessdata" -c tessedit_char_whitelist=abcdefghijklmnopqrstuvwxyzABCDEFGHIJKLMNOPQRSTUVWXYZ0123456789'
text = pytesseract.image_to_string(gray, config=custom_config)

print(text)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# File c:\Users\Sachin2\Desktop\Project\eKYC\myenv\lib\site-packages\pytesseract\pytesseract.py:255, in run_tesseract(input_filename, output_filename_base, extension, lang, config, nice, timeout)
#     254 try:
# --> 255     proc = subprocess.Popen(cmd_args, **subprocess_args())
#     256 except OSError as e:
#
# File ~\AppData\Local\Programs\Python\Python39\lib\subprocess.py:951, in Popen.__init__(self, args, bufsize, executable, stdin, stdout, stderr, preexec_fn, close_fds, shell, cwd, env, universal_newlines, startupinfo, creationflags, restore_signals, start_new_session, pass_fds, user, group, extra_groups, encoding, errors, text, umask)
#     948             self.stderr = io.TextIOWrapper(self.stderr,
#     949                     encoding=encoding, errors=errors)
# ...

# %% [markdown]
# ### Keras OCR
#  - to extract the text
#  ### This is Second Method to extract the text (but it take some time)
#  - Depand on the problem we are use the this kind of method

# %%
piplines = keras_ocr.pipeline.Pipeline()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[18], line 1
# ----> 1 piplines = keras_ocr.pipeline.Pipeline()
#
# NameError: name 'keras_ocr' is not defined

# %%
import keras_ocr
# Out:
# Unexpected exception formatting exception. Falling back to standard exception
# Traceback (most recent call last):
#   File "c:\Users\Sachin2\Desktop\Project\eKYC\myenv\lib\site-packages\IPython\core\interactiveshell.py", line 3550, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "C:\Users\Sachin2\AppData\Local\Temp\ipykernel_8208\305972813.py", line 1, in <module>
#     import keras_ocr
#   File "c:\Users\Sachin2\Desktop\Project\eKYC\myenv\lib\site-packages\keras_ocr\__init__.py", line 1, in <module>
#     from . import (
#   File "c:\Users\Sachin2\Desktop\Project\eKYC\myenv\lib\site-packages\keras_ocr\detection.py", line 28, in <module>
#     import efficientnet.tfkeras as efficientnet
#   File "c:\Users\Sachin2\Desktop\Project\eKYC\myenv\lib\site-packages\efficientnet\tfkeras.py", line 4, in <module>
#     from .preprocessing import center_crop_and_resize
# ...

# %%
import matplotlib.pyplot as plt

import keras_ocr

# keras-ocr will automatically download pretrained
# weights for the detector and recognizer.
pipeline = keras_ocr.pipeline.Pipeline()

# Get a set of three example images
images = [
    keras_ocr.tools.read(url) for url in [
        'https://upload.wikimedia.org/wikipedia/commons/b/bd/Army_Reserves_Recruitment_Banner_MOD_45156284.jpg',
        'https://upload.wikimedia.org/wikipedia/commons/e/e8/FseeG2QeLXo.jpg',
        'https://upload.wikimedia.org/wikipedia/commons/b/b4/EUBanana-500x112.jpg'
    ]
]

# Each list of predictions in prediction_groups is a list of
# (word, box) tuples.
prediction_groups = pipeline.recognize(images)

# Plot the predictions
fig, axs = plt.subplots(nrows=len(images), figsize=(20, 20))
for ax, image, predictions in zip(axs, images, prediction_groups):
    keras_ocr.tools.drawAnnotations(image=image, predictions=predictions, ax=ax)
# Out:
# Looking for C:\Users\Sachin2\.keras-ocr\craft_mlt_25k.h5
# ...
# WARNING:tensorflow:From c:\Users\Sachin2\Desktop\Project\eKYC\myenv\lib\site-packages\keras\src\backend\tensorflow\core.py:192: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[2], line 7
#       3 import keras_ocr
#       5 # keras-ocr will automatically download pretrained
#       6 # weights for the detector and recognizer.
# ----> 7 pipeline = keras_ocr.pipeline.Pipeline()
#       9 # Get a set of three example images
#      10 images = [
#      11     keras_ocr.tools.read(url) for url in [
#      12         'https://upload.wikimedia.org/wikipedia/commons/b/bd/Army_Reserves_Recruitment_Banner_MOD_45156284.jpg',
#    (...)
#      15     ]
#      16 ]
#
# ...

# %% [markdown]
# ### Now We are moving to the third Method (EasyOcr)
#  - with the help of this method we are able to extract the text

# %%
# path = "/kaggle/input/car-plate-detection/images/Cars1.png"
# reader = easyocr.Reader(['en'])
# result = reader.readtext(path)
# result

# %%
# # Tet Filtering
# threshold = 0.20
# filtertext = ""
# for text in result:
#     bounding_box  , recoginzed_text , confidence = text
#     if confidence >= threshold:
#         filtertext += str(recoginzed_text) + " "

# %% [markdown]
# ### PaddlleOCR
#  - with the help this module

# %%
from paddleocr import PaddleOCR  , draw_ocr
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[30], line 1
# ----> 1 from paddleocr import PaddleOCR  , draw_ocr
#
# ModuleNotFoundError: No module named 'paddleocr'
